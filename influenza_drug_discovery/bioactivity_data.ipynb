# %% [markdown]
# ## This Project focuses on curating a dataset for drug discovery for the Influenza HA protein

# %% [markdown]
# # Installing Libraries

# %%
# chembl web_resource client
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in c:\users\jayam\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chembl_webresource_client) (2.2.0)
# Requirement already satisfied: requests>=2.18.4 in c:\users\jayam\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting easydict (from chembl_webresource_client)
#   Downloading easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jayam\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jayam\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jayam\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in c:\users\jayam\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jayam\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.0)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: six in c:\users\jayam\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Downloading easydict-1.13-py3-none-any.whl (6.8 kB)
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: easydict, url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 easydict-1.13 requests-cache-1.2.1 url-normalize-1.4.3

# %%
# import libraries
import pandas as pd
# instantiate a new client from chembl
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # **Search for Target Protein**

# %% [markdown]
# ### *Target Search: Influenza Haemagglutinin*

# %%
target = new_client.target
# search keyword
target_query = target.search('influenza')
# convert results to a pandas dataframe
targets = pd.DataFrame.from_dict(target_query)
# dislay dataframe contents
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P03438', 'xref_name': None, 'xre...
# 5                                                 []
# 6                                                 []
# 7  [{'xref_id': 'P63231', 'xref_name': None, 'xre...
# 8                                                 []
# 9                                                 []
#
#                                          organism  \
# 0                    unidentified influenza virus
# 1                               Influenza B virus
# 2                               Influenza A virus
# 3                               Influenza C virus
# 4          Influenza A virus (strain A/X-31 H3N2)
# 5                          Influenza A virus H3N2
# 6                        Influenza A virus (H1N1)
# 7      Influenza A virus (A/Udorn/307/1972(H3N2))
# 8  Influenza A virus (A/Puerto Rico/8/1934(H1N1))
# 9                          Haemophilus influenzae
#
#                                         pref_name  score  species_group_flag  \
# 0                    unidentified influenza virus   12.0               False
# 1                               Influenza B virus   12.0               False
# 2                               Influenza A virus   12.0               False
# 3                               Influenza C virus   12.0               False
# 4                 Influenza A virus Hemagglutinin   11.0               False
# 5                          Influenza A virus H3N2   11.0               False
# 6                        Influenza A virus (H1N1)   11.0               False
# 7             Influenza virus A matrix protein M2    9.0               False
# 8  Influenza A virus (A/Puerto Rico/8/1934(H1N1))    8.0               False
# 9                          Haemophilus influenzae    7.0               False
#
#   target_chembl_id                                  target_components  \
# 0     CHEMBL613128                                                 []
# 1     CHEMBL613129                                                 []
# 2     CHEMBL613740                                                 []
# 3     CHEMBL612783                                                 []
# 4       CHEMBL4918  [{'accession': 'P03438', 'component_descriptio...
# 5    CHEMBL2366902                                                 []
# 6    CHEMBL2367089                                                 []
# 7       CHEMBL2052  [{'accession': 'P0DOF8', 'component_descriptio...
# 8     CHEMBL612610                                                 []
# 9        CHEMBL355                                                 []
#
#       target_type   tax_id
# 0        ORGANISM    11309
# 1        ORGANISM    11520
# 2        ORGANISM    11320
# 3        ORGANISM    11552
# 4  SINGLE PROTEIN   132504
# 5        ORGANISM    41857
# 6        ORGANISM  1323429
# 7  SINGLE PROTEIN   381517
# 8        ORGANISM   211044
# 9        ORGANISM      727

# %% [markdown]
# ## **Select haemagglutinin protein and retrieve bioactivity data using the target id**

# %%
influenza_target = targets.target_chembl_id[4]
influenza_target
# Out:
# 'CHEMBL4918'

# %%
# retrieve activity values
activity = new_client.activity
res = activity.filter(target_chembl_id=influenza_target).filter(standard_type="IC50")
res_df = pd.DataFrame.from_dict(res)

# %%
res_df
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     12201437                  []
# 1        None             None     12201438                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2209966  Inhibition of hemagglutininin in Influenza A v...
# 1   CHEMBL2209966  Inhibition of hemagglutininin in Influenza A v...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
#
#                           target_organism                 target_pref_name  \
# 0  Influenza A virus (strain A/X-31 H3N2)  Influenza A virus Hemagglutinin
# 1  Influenza A virus (strain A/X-31 H3N2)  Influenza A virus Hemagglutinin
#
#   target_tax_id text_value  toid  type units    uo_units upper_value value
# 0        132504       None  None  IC50    uM  UO_0000065        None   2.6
# 1        132504       None  None  IC50    uM  UO_0000065        None   3.7
#
# [2 rows x 46 columns]

# %%
res_df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# # **Save Results to CSV**

# %%
res_df.to_csv("influenza_ha_bioactivity.csv", index=False)

# %% [markdown]
# ## **Data Preparation**

# %%
inf_data = pd.read_csv('influenza_ha_bioactivity.csv')
inf_data
# Out:
#    action_type  activity_comment  activity_id activity_properties  \
# 0          NaN               NaN     12201437                  []
# 1          NaN               NaN     12201438                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2209966  Inhibition of hemagglutininin in Influenza A v...
# 1   CHEMBL2209966  Inhibition of hemagglutininin in Influenza A v...
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          B                      NaN                     NaN  BAO_0000190
# 1          B                      NaN                     NaN  BAO_0000190
#
#    ...                         target_organism  \
# 0  ...  Influenza A virus (strain A/X-31 H3N2)
# 1  ...  Influenza A virus (strain A/X-31 H3N2)
#
#                   target_pref_name target_tax_id  text_value  toid  type  \
# 0  Influenza A virus Hemagglutinin        132504         NaN   NaN  IC50
# 1  Influenza A virus Hemagglutinin        132504         NaN   NaN  IC50
#
#   units    uo_units upper_value value
# 0    uM  UO_0000065         NaN   2.6
# 1    uM  UO_0000065         NaN   3.7
#
# [2 rows x 46 columns]

# %%
# remove null and na values from standard_type column
inf_data_1 = inf_data[inf_data.standard_value.notna()]
inf_data_1
# Out:
#    action_type  activity_comment  activity_id activity_properties  \
# 0          NaN               NaN     12201437                  []
# 1          NaN               NaN     12201438                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2209966  Inhibition of hemagglutininin in Influenza A v...
# 1   CHEMBL2209966  Inhibition of hemagglutininin in Influenza A v...
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          B                      NaN                     NaN  BAO_0000190
# 1          B                      NaN                     NaN  BAO_0000190
#
#    ...                         target_organism  \
# 0  ...  Influenza A virus (strain A/X-31 H3N2)
# 1  ...  Influenza A virus (strain A/X-31 H3N2)
#
#                   target_pref_name target_tax_id  text_value  toid  type  \
# 0  Influenza A virus Hemagglutinin        132504         NaN   NaN  IC50
# 1  Influenza A virus Hemagglutinin        132504         NaN   NaN  IC50
#
#   units    uo_units upper_value value
# 0    uM  UO_0000065         NaN   2.6
# 1    uM  UO_0000065         NaN   3.7
#
# [2 rows x 46 columns]

# %% [markdown]
# ## *Label compounds as active, inactive or intermediate*
# ### Standard values that are less than 1000 nm (1 microM) are active | those greater than 10000 (10 microM) are inactive | those in-between are intermediate

# %%
# create a list to store bioactivity classes
bioactivity_class = []

# set appropriate labels
for value in inf_data_1.standard_value:
    if float(value) >= 10000:
        bioactivity_class.append("inactive")
    elif float(value) <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %%
# iterate through chembl molecule_id
mol_chembl_id = []
for id in inf_data_1.molecule_chembl_id:
    mol_chembl_id.append(id)
    
# iterate through canonical smiles
canon_smiles = []
for smile in inf_data_1.canonical_smiles:
    canon_smiles.append(smile)
    

# iterate through standard_value
stand_value = []
for value in inf_data_1.standard_value:
    stand_value.append(value)
    

# create dataframe to combine all four lists
bioactivity_data = pd.DataFrame(data = {"molecule_chembl_id": mol_chembl_id, "canonical_smiles": canon_smiles, "standard_value": stand_value, "bioactivity_class": bioactivity_class})

# %%
bioactivity_data
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL2207987        Cc1nc2sccn2c1C(=O)NN1C(=O)C(C)SC12CCC(C)CC2
# 1      CHEMBL2207978  CC1CCC2(CC1)SC(C)C(=O)N2NC(=O)C12CC3CC(CC(C3)C...
#
#    standard_value bioactivity_class
# 0          2600.0      intermediate
# 1          3700.0      intermediate
